# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# FocusGuard — Live Classical CV Demo\n",
    "\n",
    "**SELECT YOUR VENV KERNEL FIRST.**\n",
    "\n",
    "In VS Code: `Ctrl+Shift+P` → **Jupyter: Select Kernel** → pick the `.venv` inside this folder.\n",
    "\n",
    "If you skip this, `import cv2` will fail with a confusing error.\n",
    "\n",
    "## What this notebook does\n",
    "\n",
    "It runs `focusguard.py` in this notebook's kernel. The demo opens two\n",
    "OS-level windows (`FocusGuard` and `Math Panel`). To stop it, press `q`\n",
    "in the FocusGuard window, or click the square Stop button in the cell\n",
    "below.\n",
    "\n",
    "## Controls\n",
    "\n",
    "| Key | Action |\n",
    "|-----|--------|\n",
    "| `1` | Kernel Convolver panel |\n",
    "| `2` | Morphology Stamper panel |\n",
    "| `3` | Otsu Curve panel |\n",
    "| `4` | Hough Accumulator panel |\n",
    "| `k` | Cycle kernel |\n",
    "| `m` | Cycle structuring element |\n",
    "| `o` | Toggle dilate ↔ erode |\n",
    "| `l` | Toggle LAB ↔ DEMO mode |\n",
    "| `s` | Toggle liveness detection |\n",
    "| `q` | Quit (runs session report) |\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "%run focusguard.py"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Slide-to-panel mapping\n",
    "\n",
    "| Slide | Concept | Panel / Key |\n",
    "|-------|---------|-------------|\n",
    "| 3–4 | Set theory, binary dilation | Panel 2 (`2`) |\n",
    "| 5 | Binary erosion | Panel 2, `o` to toggle |\n",
    "| 6 | Opening & closing | FocusGuard mouth mask |\n",
    "| 7 | Grayscale morphology | Panel 2 (`2`) |\n",
    "| 8 | Hit-or-miss | Eye mask (FocusGuard overlay) |\n",
    "| 9 | Skeletonization | Panel 2 with `diag_5` SE |\n",
    "| 10 | SE design | `m` to cycle shapes |\n",
    "| 11–13 | Gradient, Sobel | Panel 1 (`1`), `k` → sobel_x |\n",
    "| 14 | Prewitt, Roberts | Panel 1, `k` → prewitt_x, roberts_x |\n",
    "| 15–18 | Kernel comparison | Panel 1, cycle `k` |\n",
    "| 19 | Canny pipeline | FocusGuard brow edges |\n",
    "| 20 | Harris corners | FocusGuard mouth corners |\n",
    "| 22–23 | Segmentation definition | FocusGuard ROI split |\n",
    "| 24 | Adaptive threshold | FocusGuard eye ROI |\n",
    "| 25–26 | Otsu | Panel 3 (`3`) |\n",
    "| 27 | Region growing | FocusGuard pupil seed |\n",
    "| 28 | Watershed | FocusGuard eye+brow split |\n",
    "| 29 | Hough | Panel 4 (`4`) |\n",
    "| 30 | Pipeline | Full FocusGuard window |\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 15-minute demo script\n",
    "\n",
    "1. **Start the demo.** Both windows appear. The webcam shows your face\n",
    "   with AU bars and a mood label.\n",
    "2. **Press `1`.** Move the mouse over the face. The math panel shows the\n",
    "   elementwise product + sum for the pixel under the cursor.\n",
    "3. **Press `k`.** Cycle to Sobel Y, Prewitt, Roberts, Laplacian. Point out\n",
    "   how the kernel coefficients change the products.\n",
    "4. **Press `2`.** Move the mouse. The morphology panel shows the SE\n",
    "   footprint as a green mask over the neighborhood, with the reduction\n",
    "   (max for dilate, min for erode) shown on the right.\n",
    "5. **Press `m`** twice. Show the cross SE then the ellipse SE. Explain\n",
    "   that only cells under the 1s participate.\n",
    "6. **Press `o`.** Toggle dilate ↔ erode. The reduction switches from max\n",
    "   to min.\n",
    "7. **Press `3`.** The Otsu panel appears. Point at the histogram, the\n",
    "   sigma_B^2(T) curve, and the red dot at the peak. Cover part of the\n",
    "   camera with your hand — the histogram shifts, the curve shifts, the\n",
    "   peak moves.\n",
    "8. **Press `4`.** Hough. Point at the accumulator. Say: *\"Every edge\n",
    "   pixel voted. The peak is where the votes converged.\"*\n",
    "9. **Press `l`.** Switch to DEMO mode. The math panel now auto-tracks\n",
    "   the mood detector's ROI. The banner turns red.\n",
    "10. **Hold up a printed photo of your face.** The FocusGuard window\n",
    "    shows `SPOOF?` because optical flow drops. Say: *\"Real faces move.\n",
    "    Photos don't.\"*\n",
    "11. **Press `q`.** Session report PNG is written.\n",
    "12. **Closing line.** *\"Computer vision is not a black box. It is\n",
    "    `-50 + 0 + 55 - 140 + 0 + 180 - 65 + 0 + 80 = 60`, computed 30\n",
    "    times per second, on your face.\"*\n"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## VS Code troubleshooting\n",
    "\n",
    "**Kernel not found.** `Ctrl+Shift+P` → **Jupyter: Select Kernel** → pick\n",
    "the `.venv` inside this folder.\n",
    "\n",
    "**cv2 window is blank or black.** Close the notebook and run\n",
    "`python focusguard.py` from the VS Code integrated terminal instead.\n",
    "\n",
    "**Cell won't stop.** Click the square Stop button in the cell's toolbar.\n",
    "The main loop has a `try/finally` that releases the camera on any exit.\n",
    "\n",
    "**Camera busy on next run.** `pkill -f focusguard` from the terminal, or\n",
    "wait 10 seconds.\n",
    "\n",
    "**Face DNN files missing.** The demo falls back to Haar cascades\n",
    "automatically. No action needed.\n",
    "\n",
    "## Closing line\n",
    "\n",
    "> Computer vision is not a black box. It is\n",
    "> `-50 + 0 + 55 - 140 + 0 + 180 - 65 + 0 + 80 = 60`, computed 30 times\n",
    "> per second, on your face.\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
